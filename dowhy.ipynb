# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
component = pd.read_csv('./data/skatingScores/components.csv')
technical = pd.read_csv('./data/skatingScores/technicals.csv').drop(columns = 'Unnamed: 0')
skaters = pd.read_csv('./data/skatingScores/skaters.csv')

# %%
technical
# Out:
#                 Name Country    Element  BaseValue  GOETotal   Event  \
# 0          Alysa LIU     USA       3A<<       3.30     -1.65  CRNCUP
# 1          Alysa LIU     USA        3Lz       5.90      1.18  CRNCUP
# 2          Alysa LIU     USA        3Lo       4.90      0.82  CRNCUP
# 3          Alysa LIU     USA  2A+1Eu+3S       8.10      0.86  CRNCUP
# 4          Alysa LIU     USA    FCCoSp4       3.50      0.93  CRNCUP
# ...              ...     ...        ...        ...       ...     ...
# 8887  Beres CLEMENTS     CAN         3S       4.73     -2.15  ATMCLA
# 8888  Beres CLEMENTS     CAN       3Lz<       5.19     -2.36  ATMCLA
# 8889  Beres CLEMENTS     CAN     CCoSp3       3.00      0.38  ATMCLA
# 8890  Beres CLEMENTS     CAN     StSq23       2.60     -0.07  ATMCLA
# 8891  Beres CLEMENTS     CAN    FCCoSp2       2.50     -0.19  ATMCLA
#
#      JudgeNationality IndividualGOE
# 0               J1 🇲🇽          -5.0
# 1               J1 🇲🇽           1.0
# ...

# %%
d = technical.groupby(['Event', 'Name'])['BaseValue', 'GOETotal'].sum().reset_index()
technical[(technical['Name'] == 'Yeonjeong PARK') & (technical['Event'] == 'USCLA')].drop_duplicates()


#d[d['Event'] == 'USCLA'].sort_values(by = 'GOETotal', ascending = True)
# Out:
# /Users/winsontruong/anaconda3/envs/iceskating/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                 Name Country      Element  BaseValue  GOETotal  Event  \
# 6636  Yeonjeong PARK     KOR       3Lz+3T      10.10      1.77  USCLA
# 6637  Yeonjeong PARK     KOR          3Lo       4.90      1.63  USCLA
# 6638  Yeonjeong PARK     KOR           3S       4.30      0.86  USCLA
# 6639  Yeonjeong PARK     KOR           2A       3.30      0.77  USCLA
# 6640  Yeonjeong PARK     KOR       CCoSp4       3.50      1.40  USCLA
# 6641  Yeonjeong PARK     KOR       StSq41       3.90      1.17  USCLA
# 6642  Yeonjeong PARK     KOR        2A+3T       8.25      1.26  USCLA
# 6643  Yeonjeong PARK     KOR  3Lz+2T+2Loq       9.79      0.20  USCLA
# ...

# %%
technical['Event'].value_counts()
# Out:
# LOMTRO    4536
# CRNCUP    2040
# ATMCLA    1176
# USCLA     1140
# Name: Event, dtype: int64
